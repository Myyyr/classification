# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def file_to_np(path):
    f = open(path, "r")
    txt = f.read()
    f.close()
    txt = txt.split("\n")
    dt = np.array(txt[1:-1]).astype(np.float)
    return dt

# %% [markdown]
# ## CIFAR 10
# ### ResNet-18

# %%
dt = file_to_np("results/fold_resnet18-MSSch/train_epoch_scores.csv")
plt.plot(dt)
dt = file_to_np("results/fold_resnet18-MSSch/dev_epoch_scores.csv")
plt.plot(dt)

plt.show()

dt = file_to_np("results/fold_resnet18-MSSch/trainepoch_lr_rates.csv")
plt.plot(dt)

plt.show()

# %% [markdown]
# ### RevNet-18
# #### lr : [0.1, 0.02, 0.004, 0.0008]
# #### ep : [ 60,  120,    160,    200  ]

# %%
dt = file_to_np("results/fold_resnet18_ssc/train_epoch_scores.csv")
plt.plot(dt)
dt = file_to_np("results/fold_resnet18_ssc/dev_epoch_scores.csv")
plt.plot(dt)

plt.show()

dt = file_to_np("results/fold_resnet18_ssc/trainepoch_lr_rates.csv")
plt.plot(dt)

plt.show()

# %% [markdown]
# ### RevNet-18
# #### lr : [0.1, 0.01, 0.001]

# %%
dt = file_to_np("results/fold_revnet18/train_epoch_scores.csv")
plt.plot(dt)
dt = file_to_np("results/fold_revnet18/dev_epoch_scores.csv")
plt.plot(dt)

plt.show()

dt = file_to_np("results/fold_revnet18/trainepoch_lr_rates.csv")
plt.plot(dt)

plt.show()

# %% [markdown]
# ### RevNet-18
# #### lr : [1,0.1, 0.01, 0.001, 0.0001]

# %%
dt = file_to_np("results/fold_revnet18_morelr/train_epoch_scores.csv")
plt.plot(dt)
dt = file_to_np("results/fold_revnet18_morelr/dev_epoch_scores.csv")
plt.plot(dt)

plt.show()

dt = file_to_np("results/fold_revnet18_morelr/trainepoch_lr_rates.csv")
plt.plot(dt)

plt.show()

# %% [markdown]
# ### RevNet-18
# #### lr : [0.0001, 0.001, 0.01, 0.1, 0.01, 0.001, 0.0001]
# #### patience 5

# %%
dt = file_to_np("results/fold_revnet18_trianglelr/train_epoch_scores.csv")
plt.plot(dt)
dt = file_to_np("results/fold_revnet18_trianglelr/dev_epoch_scores.csv")
plt.plot(dt)

plt.show()

dt = file_to_np("results/fold_revnet18_trianglelr/trainepoch_lr_rates.csv")
plt.plot(dt)

plt.show()

# %% [markdown]
# ### RevNet-18
# #### lr : [0.0001, 0.001, 0.01, 0.1, 0.01, 0.001, 0.0001]
# #### patience 30

# %%
dt = file_to_np("results/fold_revnet18_trianglelr_patiencemore/train_epoch_scores.csv")
plt.plot(dt)
dt = file_to_np("results/fold_revnet18_trianglelr_patiencemore/dev_epoch_scores.csv")
plt.plot(dt)

plt.show()

dt = file_to_np("results/fold_revnet18_trianglelr_patiencemore/trainepoch_lr_rates.csv")
plt.plot(dt)

plt.show()

# %% [markdown]
# ### RevNet-18
# #### lr : [0.1, 0.02, 0.004, 0.0008]
# #### ep : [ 60,  120,    160,    200  ]

# %%
dt = file_to_np("results/fold_revnet18_ssc/train_epoch_scores.csv")
plt.plot(dt)
dt = file_to_np("results/fold_revnet18_ssc/dev_epoch_scores.csv")
plt.plot(dt)

plt.show()

dt = file_to_np("results/fold_revnet18_ssc/trainepoch_lr_rates.csv")
plt.plot(dt)

plt.show()

# %% [markdown]
# ### RevNet-18
# #### CosineAnnealingLR
# #### 12, eta_min=0, last_epoch=-1

# %%
dt = file_to_np("results/fold_revnet18_callr/train_epoch_scores.csv")
plt.plot(dt)
dt = file_to_np("results/fold_revnet18_callr/dev_epoch_scores.csv")
plt.plot(dt)

plt.show()

dt = file_to_np("results/fold_revnet18_callr/trainepoch_lr_rates.csv")
plt.plot(dt)

plt.show()

# %% [markdown]
# ### RevNet-34

# %%
dt = file_to_np("results/fold_revnet34/train_epoch_scores.csv")
plt.plot(dt)
dt = file_to_np("results/fold_revnet34/dev_epoch_scores.csv")
plt.plot(dt)

plt.show()


dt = file_to_np("results/fold_revnet34/trainepoch_lr_rates.csv")
plt.plot(dt)

plt.show()

# %% [markdown]
# ### RevNet-34
# #### lr : [0.1, 0.02, 0.004, 0.0008]
# #### ep : [ 60,  120,    160,    200  ]

# %%
dt = file_to_np("results/fold_revnet34_ssc/train_epoch_scores.csv")
plt.plot(dt)
dt = file_to_np("results/fold_revnet34_ssc/dev_epoch_scores.csv")
plt.plot(dt)

plt.show()


dt = file_to_np("results/fold_revnet34_ssc/trainepoch_lr_rates.csv")
plt.plot(dt)

plt.show()

# %% [markdown]
# ### RevNet-104

# %%
dt = file_to_np("results/fold_revnet104/train_epoch_scores.csv")
plt.plot(dt)
dt = file_to_np("results/fold_revnet104/dev_epoch_scores.csv")
plt.plot(dt)

plt.show()


dt = file_to_np("results/fold_revnet104/trainepoch_lr_rates.csv")
plt.plot(dt)

plt.show()

# %% [markdown]
# ### RevNet-104
# #### lr : [0.1, 0.02, 0.004, 0.0008]
# #### ep : [ 60,  120,    160,    200  ]

# %%
dt = file_to_np("results/fold_revnet104_ssc/train_epoch_scores.csv")
plt.plot(dt)
dt = file_to_np("results/fold_revnet104_ssc/dev_epoch_scores.csv")
plt.plot(dt)

plt.show()


dt = file_to_np("results/fold_revnet104_ssc/trainepoch_lr_rates.csv")
plt.plot(dt)

plt.show()

# %% [markdown]
# ### RevNet-102
# #### lr : [0.1, 0.01, 0.001]

# %%
dt = file_to_np("results/fold_revnet102/train_epoch_scores.csv")
plt.plot(dt)
dt = file_to_np("results/fold_revnet102/dev_epoch_scores.csv")
plt.plot(dt)

plt.show()


dt = file_to_np("results/fold_revnet102/trainepoch_lr_rates.csv")
plt.plot(dt)

plt.show()

# %% [markdown]
# -----------------------------
# ## CIFAR 100
# ### ResNet-18
# #### early stoping
# #### bs 64

# %%
dt = file_to_np("results/fold_resnet18_cifar100/train_epoch_scores.csv")
plt.plot(dt)
dt = file_to_np("results/fold_resnet18_cifar100/dev_epoch_scores.csv")
plt.plot(dt)

plt.show()


dt = file_to_np("results/fold_resnet18_cifar100/trainepoch_lr_rates.csv")
plt.plot(dt)

plt.show()

# %% [markdown]
# ### ResNet-18
# #### [0.1, 0.02, 0.004, 0.0008]
# #### [ 60,  120,    160,    200  ]
# #### bs 128

# %%
dt = file_to_np("results/fold_resnet18_cifar100_ssc/train_epoch_scores.csv")
plt.plot(dt)
dt = file_to_np("results/fold_resnet18_cifar100_ssc/dev_epoch_scores.csv")
plt.plot(dt)

plt.show()


dt = file_to_np("results/fold_resnet18_cifar100_ssc/trainepoch_lr_rates.csv")
plt.plot(dt)

plt.show()
